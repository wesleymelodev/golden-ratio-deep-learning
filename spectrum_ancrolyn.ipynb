# %% [markdown]
# <a href="https://colab.research.google.com/github/wesleymelodev/golden-ratio-deep-learning/blob/main/spectrum_ancrolyn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install geoopt PyMuPDF
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.1/90.1 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.0/25.0 MB 66.8 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/Criptofantasmas/Spectrum_Ancrolyn
# Out:
# /content/drive/MyDrive/Criptofantasmas/Spectrum_Ancrolyn

# %%
# !python /content/drive/MyDrive/Criptofantasmas/Spectrum_Ancrolyn/training/training_loop.py
# Out:
# --- Iniciando Treino Hiperbólico (Hardware: cpu) ---
# Tokenizando corpus para Tensores...
# Total de tokens no dataset: 1763859
# Época 1/5:   0% 7/13779 [00:27<14:52:27,  3.89s/it, loss=12.6034]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Criptofantasmas/Spectrum_Ancrolyn/training/training_loop.py", line 141, in <module>
#     train()
#   File "/content/drive/MyDrive/Criptofantasmas/Spectrum_Ancrolyn/training/training_loop.py", line 93, in train
#     loss.backward()
#   File "/usr/local/lib/python3.12/dist-packages/torch/_tensor.py", line 631, in backward
#     torch.autograd.backward(
#   File "/usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py", line 381, in backward
#     _engine_run_backward(
#   File "/usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py", line 869, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# ...
